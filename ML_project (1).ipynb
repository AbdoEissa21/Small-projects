# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes_data=load_diabetes()
data = pd.DataFrame(data= np.c_[diabetes_data['data'], diabetes_data['target']],
                     columns= diabetes_data['feature_names'] + ['target'])

# %%
diabetes_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
diabetes_data.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of           age       sex       bmi  ...        s5        s6  target
# 0    0.038076  0.050680  0.061696  ...  0.019908 -0.017646   151.0
# 1   -0.001882 -0.044642 -0.051474  ... -0.068330 -0.092204    75.0
# 2    0.085299  0.050680  0.044451  ...  0.002864 -0.025930   141.0
# 3   -0.089063 -0.044642 -0.011595  ...  0.022692 -0.009362   206.0
# 4    0.005383 -0.044642 -0.036385  ... -0.031991 -0.046641   135.0
# ..        ...       ...       ...  ...       ...       ...     ...
# 437  0.041708  0.050680  0.019662  ...  0.031193  0.007207   178.0
# 438 -0.005515  0.050680 -0.015906  ... -0.018118  0.044485   104.0
# 439  0.041708  0.050680 -0.015906  ... -0.046879  0.015491   132.0
# 440 -0.045472 -0.044642  0.039062  ...  0.044528 -0.025930   220.0
# 441 -0.045472 -0.044642 -0.073030  ... -0.004220  0.003064    57.0
#
# [442 rows x 11 columns]>

# %%
data.isnull().sum()
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
data.describe()
# Out:
#                 age           sex  ...            s6      target
# count  4.420000e+02  4.420000e+02  ...  4.420000e+02  442.000000
# mean  -3.634285e-16  1.308343e-16  ... -3.412882e-16  152.133484
# std    4.761905e-02  4.761905e-02  ...  4.761905e-02   77.093005
# min   -1.072256e-01 -4.464164e-02  ... -1.377672e-01   25.000000
# 25%   -3.729927e-02 -4.464164e-02  ... -3.317903e-02   87.000000
# 50%    5.383060e-03 -4.464164e-02  ... -1.077698e-03  140.500000
# 75%    3.807591e-02  5.068012e-02  ...  2.791705e-02  211.500000
# max    1.107267e-01  5.068012e-02  ...  1.356118e-01  346.000000
#
# [8 rows x 11 columns]

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["target"].value_counts()
# Out:
# 200.0    6
# 72.0     6
# 90.0     5
# 178.0    5
# 71.0     5
#         ..
# 73.0     1
# 222.0    1
# 86.0     1
# 79.0     1
# 57.0     1
# Name: target, Length: 214, dtype: int64

# %%
np.corrcoef(data.iloc[:,:-1].T.astype(float))
# Out:
# array([[ 1.        ,  0.1737371 ,  0.18508467,  0.33542671,  0.26006082,
#          0.21924314, -0.07518097,  0.2038409 ,  0.27077678,  0.30173101],
#        [ 0.1737371 ,  1.        ,  0.0881614 ,  0.24101317,  0.03527682,
#          0.14263726, -0.37908963,  0.33211509,  0.14991756,  0.20813322],
#        [ 0.18508467,  0.0881614 ,  1.        ,  0.39541532,  0.24977742,
#          0.26116991, -0.36681098,  0.4138066 ,  0.44615865,  0.38867999],
#        [ 0.33542671,  0.24101317,  0.39541532,  1.        ,  0.24246971,
#          0.18555783, -0.17876121,  0.25765337,  0.39347814,  0.39042938],
#        [ 0.26006082,  0.03527682,  0.24977742,  0.24246971,  1.        ,
#          0.89666296,  0.05151936,  0.54220728,  0.51550076,  0.32571675],
#        [ 0.21924314,  0.14263726,  0.26116991,  0.18555783,  0.89666296,
#          1.        , -0.19645512,  0.65981689,  0.3183534 ,  0.29060038],
#        [-0.07518097, -0.37908963, -0.36681098, -0.17876121,  0.05151936,
# ...

# %%
import seaborn as sns

sns.boxplot(data.iloc[:,:-1].values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Not working right

# %%
from sklearn.linear_model import LinearRegression

# %%
LR_model = LinearRegression()

# %%
X=data.iloc[:,:1]
y=data.iloc[:,-1]

# %%
X,y
# Out:
# (          age
#  0    0.038076
#  1   -0.001882
#  2    0.085299
#  3   -0.089063
#  4    0.005383
#  ..        ...
#  437  0.041708
#  438 -0.005515
#  439  0.041708
#  440 -0.045472
#  441 -0.045472
#
#  [442 rows x 1 columns], 0      151.0
#  1       75.0
#  2      141.0
#  3      206.0
#  4      135.0
#         ...
#  437    178.0
#  438    104.0
#  439    132.0
#  440    220.0
#  441     57.0
#  Name: target, Length: 442, dtype: float64)

# %%
LR_model.fit(X,y)
# Out:
# LinearRegression()

# %%
LR_model.intercept_
# Out:
# 152.13348416289605

# %%
LR_model.coef_
# Out:
# array([304.18307453])

# %%
LR_model.score(X,y)
# Out:
# 0.03530218264671636

# %%
pred = LR_model.predict(X)

# %%
plt.scatter(X,y, color="red")

plt.plot(X,pred, color="k")

plt.title("Diabeats")

plt.xlabel("Age")

plt.ylabel("Target")

plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_feat = PolynomialFeatures(degree=4)

X_poly = poly_feat.fit_transform(X)

# %%
poly_model = LinearRegression()

poly_model.fit(X_poly, y)

predicitons = poly_model.predict(X_poly)

poly_model.score(X_poly, y)
# Out:
# 0.03648184185786907

# %% [markdown]
# Score is so low because one feature were used and also this not linier because the target in not quantitative value

# %%
plt.scatter(X, y, color='red')
plt.plot(X, predicitons, color='blue')
plt.title('Poly_Diabeats')
plt.xlabel('Age')
plt.ylabel('Target')
plt.show()

# %%
X2=data.iloc[:,:-1]
X2
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 0    0.038076  0.050680  0.061696  ... -0.002592  0.019908 -0.017646
# 1   -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068330 -0.092204
# 2    0.085299  0.050680  0.044451  ... -0.002592  0.002864 -0.025930
# 3   -0.089063 -0.044642 -0.011595  ...  0.034309  0.022692 -0.009362
# 4    0.005383 -0.044642 -0.036385  ... -0.002592 -0.031991 -0.046641
# ..        ...       ...       ...  ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  ... -0.002592  0.031193  0.007207
# 438 -0.005515  0.050680 -0.015906  ...  0.034309 -0.018118  0.044485
# 439  0.041708  0.050680 -0.015906  ... -0.011080 -0.046879  0.015491
# 440 -0.045472 -0.044642  0.039062  ...  0.026560  0.044528 -0.025930
# 441 -0.045472 -0.044642 -0.073030  ... -0.039493 -0.004220  0.003064
#
# [442 rows x 10 columns]

# %%
LR_model2 = LinearRegression()

# %%
LR_model2.fit(X2,y)
# Out:
# LinearRegression()

# %%
LR_model2.intercept_
# Out:
# 152.1334841628965

# %%
LR_model2.coef_
# Out:
# array([ -10.01219782, -239.81908937,  519.83978679,  324.39042769,
#        -792.18416163,  476.74583782,  101.04457032,  177.06417623,
#         751.27932109,   67.62538639])

# %%
LR_model2.score(X2,y)
# Out:
# 0.5177494254132934

# %% [markdown]
# Score slightly better after using all features but still so low

# %%
pred = LR_model.predict(X2)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - bmi
# - bp
# - s1
# - s2
# - s3
# - ...
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-99a4e1ab5abf> in <module>()
# ----> 1 pred = LR_model.predict(X2)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ...

# %%
poly_feat = PolynomialFeatures(degree=2)

X_poly = poly_feat.fit_transform(X2)

# %%
X_poly.shape
# Out:
# (442, 66)

# %%
poly_model = LinearRegression()

poly_model.fit(X_poly, y)

predicitons = poly_model.predict(X_poly)

poly_model.score(X_poly, y)
# Out:
# 0.5924394264411932

# %% [markdown]
# Not linear problem

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.2, random_state=1)

# %%
LR_model2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LR_model2.intercept_
# Out:
# 151.43006895898006

# %%
pred = LR_model.predict(X_test)
pred
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - bmi
# - bp
# - s1
# - s2
# - s3
# - ...
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-12024a567619> in <module>()
# ----> 1 pred = LR_model.predict(X_test)
#       2 pred
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ...

# %%
LR_model2.score(X_train,y_train)

# %%
LR_model2.score(X_test,y_test)
# Out:
# 0.43843604017332694

# %%
poly_feat = PolynomialFeatures(degree=2)

X_poly = poly_feat.fit_transform(X_train)
X_poly
# Out:
# array([[ 1.00000000e+00, -5.51455498e-03,  5.06801187e-02, ...,
#          3.28271610e-04, -8.05999792e-04,  1.97895780e-03],
#        [ 1.00000000e+00,  1.26481373e-02,  5.06801187e-02, ...,
#          5.78526760e-04,  7.71105562e-04,  1.02778960e-03],
#        [ 1.00000000e+00,  7.07687525e-02, -4.46416365e-02, ...,
#          6.44811301e-04, -1.32547198e-04,  2.72463581e-05],
#        ...,
#        [ 1.00000000e+00, -8.54304009e-02,  5.06801187e-02, ...,
#          9.29936648e-03,  3.29941960e-03,  1.17063562e-03],
#        [ 1.00000000e+00,  6.71362140e-02,  5.06801187e-02, ...,
#          2.64741942e-05, -2.50203904e-04,  2.36464207e-03],
#        [ 1.00000000e+00, -9.14709343e-03, -4.46416365e-02, ...,
#          2.90263881e-04, -8.89304990e-05,  2.72463581e-05]])

# %%
poly_model = LinearRegression()

poly_model.fit(X_poly, y_train)

predicitons = poly_model.predict(X_poly)
predicitons
# Out:
# array([ 80., 128., 160., 208.,  16.,  96.,  96., 240.,  80., 128., 192.,
#        144., 128., 144., 112., 272.,  96., 320., 288., 208.,  80., 192.,
#        208., 256., 144., 144., 176., 224., 224., 192., 112.,  48., 336.,
#        176., 176., 128., 144., 144., 176., 160., 144., 160., 208., 208.,
#        256., 112., 192., 112.,  80.,  32.,  32., 240.,  64., 128., 128.,
#         80.,  96.,  96., 224., 128., 112., 304., 192., 192., 128., 192.,
#         64., 144., 208., 144.,  96., 112., 224., 272.,  96., 160., 288.,
#        128., 288.,  16., 192., 176., 224.,  16., 240.,  64., 208., 320.,
#         48., 240., 176., 240.,  96., 224.,  96., 320., 112.,  64., 192.,
#        192., 304.,  80., 176., 160., 288., 272., 224., 224., 272.,  96.,
#        192., 240., 224., 112., 176., 288.,  64., 160., 112., 272.,  48.,
#        160., 160., 144., 256.,  48., 144.,  80., 208., 160., 208., 288.,
#        160.,  96., 176., 144.,  64., 192., 176., 256., 128., 224., 128.,
# ...

# %%
poly_model.score(X_poly, y_train)
# Out:
# 0.20353667804814823

# %% [markdown]
# Not sure i made it right this way

# %% [markdown]
# can't use Lasso and ridge regression because its underfit in both models
